# %%
import pandas as pd
import numpy as np
import os


search_dir = "/home/n7487/Downloads/Geo/data/"
os.chdir(search_dir)
files = filter(os.path.isfile, os.listdir(search_dir))
files = [os.path.join(search_dir, f) for f in files]
files = [x for x in files if x.endswith('xlsx')]


df_kolkata = []
df_lucknow = []
count_kolkata = 0
count_lucknow = 0
start_index = 16

# %% [markdown]
# ## add_PM_values(df,df1)
# ### There are a lot of 'None' values in the data collated from CPCB.
# ### To Calculate the averages, I'm mainting a counter which gets reduced by 1 each time a 'None' is detected in the dataframes. I'm also resetting the 'None' PM2.5 value to be 0.
# ### Finally adding the PM2.5 values and the counter to later find accurate averages.

# %%
def add_PM_values(df,df1):

    if 'None' in df['PM2.5'].values:
        df['PM2.5']= df['PM2.5'].astype(str)
        df.loc[df['PM2.5'].str.lower().isin(['none']), 'count'] -= 1             
        df.loc[df['PM2.5'] == 'None', 'PM2.5'] = 0
        df['PM2.5']= df['PM2.5'].astype(float64)
        
    if 'None' in df1['PM2.5'].values:
        df1['PM2.5']= df1['PM2.5'].astype(str)
        df1.loc[df1['PM2.5'].str.lower().isin(['none']), 'count'] -= 1            
        df1.loc[df1['PM2.5'] == 'None', 'PM2.5'] = 0
        df1['PM2.5']= df1['PM2.5'].astype(np.float64)
    df['PM2.5'] = df['PM2.5'] + df1['PM2.5']
    df['count'] = df['count'] + df1['count']
    return df

# %% [markdown]
# ### Collecting data for all stations in Lucknow and Kolata

# %%
for f in files:
    df_temp = pd.read_excel(f)
    df_temp.columns = ['From', 'To', 'PM2.5']
    df_temp['count'] = 1
    if df_temp.iloc[4]['To'] == 'Lucknow':                # df_temp.iloc[4]['To'] is the city name
        if len(df_lucknow)==0:
            df_lucknow = df_temp[start_index:].reset_index(drop=True)
        else:
            df_lucknow = add_PM_values(df_lucknow, df_temp[start_index:].reset_index(drop=True))
    else:
        if len(df_kolkata)==0:
            df_kolkata = df_temp[start_index:].reset_index(drop=True)
        else:
            df_kolkata = add_PM_values(df_kolkata, df_temp[start_index:].reset_index(drop=True))

# %% [markdown]
# ### Calculating each day's PM2.5 average across all stations for both cities using the initial counter consisting of non-zero values

# %%
df_lucknow['PM2.5_StationAverage'] = df_lucknow['PM2.5'] /df_lucknow['count'] 
df_kolkata['PM2.5_StationAverage'] = df_kolkata['PM2.5'] /df_kolkata['count']

# %% [markdown]
# ### Output:

# %%
df_lucknow
# Out:
#                  From                To    PM2.5  count PM2.5_StationAverage
# 0    01-01-2020 00:00  02-01-2020 00:00  1094.75      4             273.6875
# 1    02-01-2020 00:00  03-01-2020 00:00   709.23      4             177.3075
# 2    03-01-2020 00:00  04-01-2020 00:00    474.5      4              118.625
# 3    04-01-2020 00:00  05-01-2020 00:00   418.49      4             104.6225
# 4    05-01-2020 00:00  06-01-2020 00:00   396.39      4              99.0975
# ..                ...               ...      ...    ...                  ...
# 903  22-06-2022 00:00  23-06-2022 00:00   213.67      5               42.734
# 904  23-06-2022 00:00  24-06-2022 00:00   258.45      5                51.69
# 905  24-06-2022 00:00  25-06-2022 00:00   275.22      5               55.044
# 906  25-06-2022 00:00  26-06-2022 00:00   261.87      5               52.374
# 907  26-06-2022 00:00  26-06-2022 20:27   194.71      5               38.942
#
# [908 rows x 5 columns]

# %%
df_kolkata
# Out:
#                  From                To   PM2.5  count PM2.5_StationAverage
# 0    01-01-2020 00:00  02-01-2020 00:00  630.43      5              126.086
# 1    02-01-2020 00:00  03-01-2020 00:00  675.82      6           112.636667
# 2    03-01-2020 00:00  04-01-2020 00:00  298.24      6            49.706667
# 3    04-01-2020 00:00  05-01-2020 00:00  306.18      6                51.03
# 4    05-01-2020 00:00  06-01-2020 00:00  541.81      6            90.301667
# ..                ...               ...     ...    ...                  ...
# 903  22-06-2022 00:00  23-06-2022 00:00  114.86      6            19.143333
# 904  23-06-2022 00:00  24-06-2022 00:00   92.87      6            15.478333
# 905  24-06-2022 00:00  25-06-2022 00:00  106.71      6               17.785
# 906  25-06-2022 00:00  26-06-2022 00:00  113.51      6            18.918333
# 907  26-06-2022 00:00  26-06-2022 20:21   78.46      6            13.076667
#
# [908 rows x 5 columns]

# %%
df_lucknow.to_csv('./df_lucknow.csv',index=None)
df_kolkata.to_csv('./df_kolkata.csv',index=None)

# %% [markdown]
# ## Calculate Moving Averages

# %%
window = 365
lucknow_average_data = []
for ind in range(len(df_lucknow) - window + 1):
    lucknow_average_data.append(np.mean(df_lucknow['PM2.5_StationAverage'][ind:ind+window]))

kolkata_average_data = []
for ind in range(len(df_kolkata) - window + 1):
    kolkata_average_data.append(np.mean(df_kolkata['PM2.5_StationAverage'][ind:ind+window]))

# %% [markdown]
# ### Plotting Moving Averages

# %%
import plotly.graph_objs as go
fig = go.Figure()

# %%
len(lucknow_average_data)
# Out:
# 544

# %%
df_lucknow[:len(lucknow_average_data)].shape
# Out:
# (544, 5)

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=df_lucknow[:len(lucknow_average_data)]['From'],y=lucknow_average_data,name="Lucknow") )
fig.add_trace(go.Scatter(x=df_kolkata[:len(kolkata_average_data)]['From'],y=kolkata_average_data,name="Kolkata") )
fig.show()
# Out:
# <div>                            <div id="becd9024-83fb-4d7f-8707-6956505baa36" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("becd9024-83fb-4d7f-8707-6956505baa36")) {                    Plotly.newPlot(                        "becd9024-83fb-4d7f-8707-6956505baa36",                        [{"name":"Lucknow","x":["01-01-2020 00:00","02-01-2020 00:00","03-01-2020 00:00","04-01-2020 00:00","05-01-2020 00:00","06-01-2020 00:00","07-01-2020 00:00","08-01-2020 00:00","09-01-2020 00:00","10-01-2020 00:00","11-01-2020 00:00","12-01-2020 00:00","13-01-2020 00:00","14-01-2020 00:00","15-01-2020 00:00","16-01-2020 00:00","17-01-2020 00:00","18-01-2020 00:00","19-01-2020 00:00","20-01-2020 00:00","21-01-2020 00:00","22-01-2020 00:00","23-01-2020 00:00","24-01-2020 00:00","25-01-2020 00:00","26-01-2020 00:00","27-01-2020 00:00","28-01-2020 00:00","29-01-2020 00:00","30-01-2020 00:00","31-01-2020 00:00","01-02-2020 00:00","02-02-2020 00:00","03-02-2020 00:00","04-02-2020 00:00","05-02-2020 00:00","06-02-2020 00:00","07-02-2020 00:00","08-02-2020 00:00","09-02-2020 00:00","10-02-2020 00:00","11-02-2020 00:00","12-02-2020 00:00","13-02-2020 00:00","14-02-2020 00:00","15-02-2020 00:00","16-02-2020 00:00","17-02-2020 00:00","18-02-2020 00:00","19-02-2020 00:00","20-02-2020 00:00","21-02-2020 00:00","22-02-2020 00:00","23-02-2020 00:00","24-02-2020 00:00","25-02-2020 00:00","26-02-2020 00:00","27-02-2020 00:00","28-02-2020 00:00","29-02-2020 00:00","01-03-2020 00:00","02-03-2020 00:00","03-03-2020 00:00","04-03-2020 00:00","05-03-2020 00:00","06-03-2020 00:00","07-03-2020 00:00","08-03-2020 00:00","09-03-2020 00:00","10-03-2020 00:00","11-03-2020 00:00","12-03-2020 00:00","13-03-2020 00:00","14-03-2020 00:00","15-03-2020 00:00","16-03-2020 00:00","17-03-2020 00:00","18-03-2020 00:00","19-03-2020 00:00","20-03-2020 00:00","21-03-2020 00:00","22-03-2020 00:00","23-03-2020 00:00","24-03-2020 00:00","25-03-2020 00:00","26-03-2020 00:00","27-03-2020 00:00","28-03-2020 00:00","29-03-2020 00:00","30-03-2020 00:00","31-03-2020 00:00","01-04-2020 00:00","02-04-2020 00:00","03-04-2020 00:00","04-04-2020 00:00","05-04-2020 00:00","06-04-2020 00:00","07-04-2020 00:00","08-04-2020 00:00","09-04-2020 00:00","10-04-2020 00:00","11-04-2020 00:00","12-04-2020 00:00","13-04-2020 00:00","14-04-2020 00:00","15-04-2020 00:00","16-04-2020 00:00","17-04-2020 00:00","18-04-2020 00:00","19-04-2020 00:00","20-04-2020 00:00","21-04-2020 00:00","22-04-2020 00:00","23-04-2020 00:00","24-04-2020 00:00","25-04-2020 00:00","26-04-2020 00:00","27-04-2020 00:00","28-04-2020 00:00","29-04-2020 00:00","30-04-2020 00:00","01-05-2020 00:00","02-05-2020 00:00","03-05-2020 00:00","04-05-2020 00:00","05-05-2020 00:00","06-05-2020 00:00","07-05-2020 00:00","08-05-2020 00:00","09-05-2020 00:00","10-05-2020 00:00","11-05-2020 00:00","12-05-2020 00:00","13-05-2020 00:00","14-05-2020 00:00","15-05-2020 00:00","16-05-2020 00:00","17-05-2020 00:00","18-05-2020 00:00","19-05-2020 00:00","20-05-2020 00:00","21-05-2020 00:00","22-05-2020 00:00","23-05-2020 00:00","24-05-2020 00:00","25-05-2020 00:00","26-05-2020 00:00","27-05-2020 00:00","28-05-2020 00:00","29-05-2020 00:00","30-05-2020 00:00","31-05-2020 00:00","01-06-2020 00:00","02-06-2020 00:00","03-06-2020 00:00","04-06-2020 00:00","05-06-2020 00:00","06-06-2020 00:00","07-06-2020 00:00","08-06-2020 00:00","09-06-2020 00:00","10-06-2020 00:00","11-06-2020 00:00","12-06-2020 00:00","13-06-2020 00:00","14-06-2020 00:00","15-06-2020 00:00","16-06-2020 00:00","17-06-2020 00:00","18-06-2020 00:00","19-06-2020 00:00","20-06-2020 00:00","21-06-2020 00:00","22-06-2020 00:00","23-06-2020 00:00","24-06-2020 00:00","25-06-2020 00:00","26-06-2020 00:00","27-06-2020 00:00","28-06-2020 00:00","29-06-2020 00:00","30-06- ...

# %%
fig.write_html("MovingAvgsLucknowKolkata.html")
